# %% [markdown]
# # AI Owners Club
# # [OwnersClub.ai](https://ownersclub.ai)
# ## _Own Your Own AI_
# ### Welcome & Logistics
#
# * **Goal:** Collaborative development and support for owning your own AI.
# * **Logistics:** Bring your laptop (if you want to).
# * **Overview** of the 2.5-hour agenda
#     * First Hour: Getting started with Jan
#     * Second Hour: Digging into the technology
#     * Final Half Hour: Feedback and planning for the Owners Club

# %% [markdown]
# # What is Jan
#
# ## [Jan.ai](https://jan.ai)
# ## A local-first ChatGPT clone and model hub
#
# ![image.png](attachment:e07cd65f-d272-4a70-9a5d-f925b0c6fd32.png)
#
# ## [OSS Apache 2 License](https://www.apache.org/licenses/LICENSE-2.0)
#
# ## GitHub Repo: https://github.com/janhq/jan
# ## Releases on GitHub: https://github.com/janhq/jan/releases

# %% [markdown]
# # OwnersClub hotspot at the Hacker Dojo
# ## WiFI
# ### SSID: OwnersClub
# ### password: **local-first-ai**
#
# ## Local Site
# ### [http://wiki3.local](http://wiki3.local)
# ### Mirrors for Jan.ai releases and some models
#
# ## **NOTICE**
# This hotspot runs a caching web service to optimize model downloading.
# We try to avoid interfering with other web sites or snooping on you so just FYI.
#
# There is a certificate if you want to trust it and use SSL but it is not required (or even recommended).

# %% [markdown]
# # Privacy: Jan metrics
#
# Jan has usage metrics collection enabled by default:
#
# ![Privacy Settings Analystics Enabled](attachment:4285715b-4fb5-4b86-b77b-3a6b523da672.png)

# %% [markdown]
# # Your First Local LLM
#
# ## For folks at HD:
# ### Configure the proxy settings
#
# ## Download the model from the Jan Hub
# ### Filter, choose, download.
#
# ## [Hello World]
# ### Start a new chat, type some simple message and hit enter or click go button

# %% [markdown]
# # Using the `exa` Search MCP
#
# ## https://exa.ai/mcp
#
# ### Free tier: 20,000 searches per month
#
# ## Try a message that needs current news like [What's happening in the World Cup?]
#
# ### MCP tool search permission dialog
#
# ###

# %% [markdown]
# # Using the local files MCP
#
# * Is this the way to go?  It requires NodeJS and not contained, so certainly optional.

# %% [markdown]
# # Using OpenRouter, a cloud LLM service
#
# ## What if I need more performance that my machine has?

# %% [markdown]
# # The Philosophy of Owning Your AI
# ### Why Local-First AI?
#
# * Personal AI will make Personal Computers actually personal (again).
# * This echoes the 1970s homebrew computer era, when we built our own systems due to a lack of choices.
# * Comparing the bespoke nature of Web1 and repersonalization of Web3 to the big tech hegemony of Web2.
# * Why open-source software (OSS) and "free as in freedom" are crucial to owning your AI.

# %% [markdown]
# # Understanding the Technology
# ### What is an LLM?
#
# * LLMs are pure functions in software systems which are otherwise pretty much just ordinary applications.
# * They solve the incredibly difficult problem of understanding and using human language.
# * They are computationally expensive.
# * There are wide variations in performance with big factors including size, training data & method, and inference algorithm.

# %% [markdown]
# # Analogies for AI
# ### How do we think about AI?
#
# * **The Electricity Analogy:**
# Andrew Ng: ["AI is the new electricity"](https://scet.berkeley.edu/ai-is-the-new-electricity-insights-from-dr-andrew-ng/)
#
# And we're not in the 1880s yet, we're much much closer to the mid/late 1700s (Lyden Jar) and early 1800s (Voltaic Pile).
#
# https://library.si.edu/exhibition/fantastic-worlds/body-electric

# %% [markdown]
# # Analogies for AI
#
# * **Car Ownership**
#
# * Owning an AI is like owning a car.
# * The CPU & GPU are engine and turbo.  An agent harness is a chassis. This can go on for dashboard, windows, body, etc.
#
# * **But an AI isn't a car**
#
# * It is, or can be, a riding mechanic and tools for modifying the car, and even a car factory too.
# https://connorskelly.substack.com/p/building-plane-while-flying-burnout
#
# <img src="https://substackcdn.com/image/fetch/$s_!D2QH!,f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fbucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com%2Fpublic%2Fimages%2Fd5d9fdc4-36f2-490f-8a09-5fcad3da17fa_1920x1536.png" width="400" alt="An airplane being built while it flies"/>

# %% [markdown]
# # Tools and Solutions
# ### Toolset Overview
#
# * **Local Applications:** Jan.ai (Mac, Win, Linux), LMStudio.ai (Mac, Win, Linux), and Osaurus.ai (Mac).
# * **Browser & Server Tools:** WebLLM, Home Assistant, and the Wiki3.ai Web Proxy / IPFS Model Server.

# %% [markdown]
# # Solving the RAG Problem
# ### Adding Document Intelligence to Jan.ai
#
# * **The Problem:** Jan.ai does not support built-in RAG, meaning you can't drop a folder of PDFs into it to ask questions directly.
# * **The Solution:** Layer Jan.ai as a clean, privacy-first UI over Haystack and Open WebUI.
# * Haystack indexes documents locally, and Open WebUI provides RAG via an OpenAI-compatible API to connect with Jan.ai, keeping all data on your machine.

# %% [markdown]
# # Hands-On Application
# ### Setup & Configuration
#
# * Walkthrough of Jan.ai installation for Mac and Windows.
# * Connecting to models using OpenAI-compatible APIs.
# * Utilizing free tiers, such as Groq and OpenRouter, and exploring task-based model routing.

# %% [markdown]
# # Expanding Capabilities
# ### Advanced Integration
#
# * Integrating tools and skills like web search and research.
# * Exploring Model Context Protocol (MCP) servers and tools.

# %% [markdown]
# # Workshop Practice & Conclusion
# ### Practice & Problem Solving
#
# * **Workshop / Fix It:** Bring your AI ownership issues and questions, and we'll work on them with you.
# * **Member Demos:** Show the group what you did or learned in the class.

# %% [markdown]
# # Community & Feedback
# ### What's Next?
#
# * Gathering feedback on what use cases to cover next and how to improve the class.
# * This class is Open Source—we are seeking people to localize, customize, and deliver the class themselves.
